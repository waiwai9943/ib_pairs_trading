# %%
import os
import pandas as pd

# Specify the folder path where the CSV files are located
folder_path = 'pairs_data'

# Get a list of all CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# Iterate over the CSV files
for file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Check if the 'signal' column of the last row is 1
    if df['numUnits'].iloc[-1] == 1:
        # Print the file name
        print(file,'\n',df)
# Out:
# KEY-PRU.csv
#                            Date          x          y        hr    zScore  \
# 0    2023-04-25 00:00:00-04:00  10.074038  81.489326 -6.563686  1.715719
# 1    2023-04-26 00:00:00-04:00  10.150940  81.314461 -6.614789  0.909896
# 2    2023-04-27 00:00:00-04:00  10.525832  83.150589 -6.665544  0.300163
# 3    2023-04-28 00:00:00-04:00  10.823824  84.520401 -6.713643 -0.400025
# 4    2023-05-01 00:00:00-04:00  10.304742  83.850067 -6.764167  0.553668
# ..                         ...        ...        ...       ...       ...
# 109  2023-09-29 00:00:00-04:00  10.760000  94.889999 -8.100042 -2.001675
# 110  2023-10-02 00:00:00-04:00  10.450000  93.379997 -8.120361 -1.100437
# 111  2023-10-03 00:00:00-04:00  10.070000  91.339996 -8.140214 -0.442220
# 112  2023-10-04 00:00:00-04:00  10.250000  91.190002 -8.156440 -1.131821
# 113  2023-10-05 00:00:00-04:00  10.300000  91.839996 -8.170239 -0.825022
#
#      numUnits  cum rets
# 0        -1.0  0.988803
# 1        -1.0  0.996875
# 2        -1.0  1.004558
# 3         0.0  1.011792
# 4         0.0  1.011792
# ..        ...       ...
# 109       1.0  0.964739
# 110       1.0  0.969164
# 111       1.0  0.974045
# 112       1.0  0.963852
# 113       1.0  0.964421
#
# [114 rows x 7 columns]
# NI-XEL.csv
#                            Date          x          y        hr    zScore  \
# 0    2023-03-08 00:00:00-05:00  27.209902  62.794144 -2.305654  0.319877
# 1    2023-03-09 00:00:00-05:00  26.895563  62.647881 -2.298621  1.666597
# 2    2023-03-10 00:00:00-05:00  26.237417  61.643566 -2.293403  1.979888
# 3    2023-03-13 00:00:00-04:00  26.846449  63.671700 -2.290332  1.898199
# 4    2023-03-14 00:00:00-04:00  27.268841  64.320412 -2.287969  1.188385
# ..                         ...        ...        ...       ...       ...
# 147  2023-10-06 00:00:00-04:00  24.590000  57.349998 -2.148396 -1.698722
# 148  2023-10-09 00:00:00-04:00  25.139999  57.650002 -2.155393 -2.041981
# 149  2023-10-10 00:00:00-04:00  25.459999  58.060001 -2.160319 -1.639249
# 150  2023-10-11 00:00:00-04:00  26.049999  58.810001 -2.163126 -1.501296
# 151  2023-10-12 00:00:00-04:00  25.725000  58.480000 -2.165315 -1.011348
#
#      numUnits  cum rets
# 0         0.0  1.000000
# 1         0.0  1.000000
# 2         0.0  1.000000
# 3         0.0  1.000000
# 4         0.0  1.000000
# ..        ...       ...
# 147       0.0  1.010517
# 148       1.0  1.010517
# 149       1.0  1.006933
# 150       1.0  1.001743
# 151       1.0  1.004516
#
# [152 rows x 7 columns]
# PGR-SPGI.csv
#                            Date           x           y        hr    zScore  \
# 0    2023-04-28 00:00:00-04:00  136.198441  360.822845 -2.543677  1.493725
# 1    2023-05-01 00:00:00-04:00  135.689194  360.892517 -2.555616  1.056495
# 2    2023-05-02 00:00:00-04:00  128.120407  354.294647 -2.575861  1.687616
# 3    2023-05-03 00:00:00-04:00  124.865219  348.273956 -2.596173  1.188851
# 4    2023-05-04 00:00:00-04:00  125.913666  345.825897 -2.610318  0.203970
# ..                         ...         ...         ...       ...       ...
# 112  2023-10-09 00:00:00-04:00  143.259995  366.470001 -2.634966  0.814396
# 113  2023-10-10 00:00:00-04:00  142.250000  369.579987 -2.629385  1.635721
# 114  2023-10-11 00:00:00-04:00  143.860001  371.899994 -2.623481  1.224255
# 115  2023-10-12 00:00:00-04:00  143.300003  365.820007 -2.615237  0.435222
# 116  2023-10-13 00:00:00-04:00  154.399994  365.282990 -2.589469 -2.034945
#
#      numUnits  cum rets
# 0        -1.0  0.998632
# 1        -1.0  0.998992
# 2        -1.0  0.984158
# 3        -1.0  0.984414
# 4         0.0  0.994719
# ..        ...       ...
# 112       0.0  1.081298
# 113       0.0  1.081298
# 114       0.0  1.081298
# 115       0.0  1.081298
# 116       1.0  1.081298
#
# [117 rows x 7 columns]
